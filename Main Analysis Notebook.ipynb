# %% [markdown]
# # Zillow Real Estate Time Series Analysis

# %% [markdown]
# ## 1. Business Use Case and Project Overview
#
#
# Our proposed client would be a real estate investment firm, looking to find out which cities in New York State are the most optimal for short term investment, in this case a year from now. Investors want data driven decisions, and this analysis gives them what they need to narrow down their search, and make prudent choices on where to invest their money.
#
# Our dataset comes from Zillow, and tracks the median home price for many of the country's major metro areas. These metro areas are denoted by zillows internal 'Msa' designation, which stands for 'Metropolitan Statistical Area', meaning there are more than 50,000 people living in an urbanized area. The raw dataset covers 909 American metro areas, tracking the median home value for each from January of 2000 to September of 2021.
#
# Because our business use-case is focused solely on New York, we will filter this dataset down to include only metro areas within New York State. We will also only be using data from 2012 onwards, as the housing crash of 2008 was a relatively rare event for the famously stable housing market. Since we are only making predictions for one year out, the crash might skew our predictions.

# %% [markdown]
# ## 2. Exploratory Data Analysis and Data Preparation

# %% [markdown]
# ### 2.1 Importing the Necessary Libraries and packages

# %%
# Importing what we need 
import numpy as np 
e = np.e
import pandas as pd 
import matplotlib
import statsmodels.api as sm 
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', None)

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima.arima import auto_arima

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### 2.2 Importing the Zillow Data as a Pandas Dataframe

# %%
# Importing the data from the csv 
df = pd.read_csv('Data/zillow_metro_areas.csv')

# Taking a look at the shape of the dataset
print(df.shape)

# This line will tell us how many of our rows represent metro areas
print(df.RegionType.value_counts())

# Examining the first five rows of our dataframe
df.head()
# Out:
# (909, 266)
# Msa        908
# Country      1
# Name: RegionType, dtype: int64
#    RegionID  SizeRank                          RegionName RegionType  \
# 0    102001         0                       United States    Country
# 1    394913         1                        New York, NY        Msa
# 2    753899         2  Los Angeles-Long Beach-Anaheim, CA        Msa
# 3    394463         3                         Chicago, IL        Msa
# 4    394514         4               Dallas-Fort Worth, TX        Msa
#
#   StateName  2000-01-31  2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  \
# 0       NaN    127569.0    127914.0    128277.0    129016.0    129762.0  ...
# 1        NY    225438.0    226785.0    227997.0    230383.0    232604.0  ...
# 2        CA    231209.0    232014.0    233247.0    235592.0    238105.0  ...
# 3        IL    170602.0    171004.0    171525.0    172568.0    173673.0  ...
# 4        TX    130189.0    130293.0    130379.0    130591.0    130813.0  ...
#
# ...

# %% [markdown]
# So in the raw dataframe, we have 909 rows, with 266 columns. Of those 266 columns, 5 of them describe the metro area represented by each row. Columns 6 through 266 represent a time series that spans from January of 2000, to September of 2021. The values are the median home price for that metro area on that specific month.
#
# Of our 909 rows, the first is the only row that represents a region other than a metro area, it tracks the median home price for the entire US.

# %% [markdown]
# ### 2.3 Filtering by NY
#
# Our client only operates within New York State, so we need to filter down our raw dataframe to only look at metro area where 'NY' is designated for the StateName column.

# %%
# Making a dataframe of just New York
df_ny = df[df['StateName'] == 'NY']

# Seeing how many rows we get 
print(df_ny.shape)

# Sanity check 
df_ny.head()
# Out:
# (26, 266)
#     RegionID  SizeRank     RegionName RegionType StateName  2000-01-31  \
# 1     394913         1   New York, NY        Msa        NY    225438.0
# 47    394425        47    Buffalo, NY        Msa        NY     93968.0
# 51    395031        51  Rochester, NY        Msa        NY    100972.0
# 60    394308        60     Albany, NY        Msa        NY    108218.0
# 79    395143        79   Syracuse, NY        Msa        NY     83512.0
#
#     2000-02-29  2000-03-31  2000-04-30  2000-05-31  ...  2020-12-31  \
# 1     226785.0    227997.0    230383.0    232604.0  ...    514350.0
# 47     94487.0     94871.0     95602.0     96126.0  ...    194644.0
# 51    100678.0    100670.0    100915.0    101426.0  ...    173209.0
# 60    108769.0    109063.0    109786.0    110293.0  ...    221148.0
# 79     83785.0     84042.0     84537.0     85003.0  ...    161572.0
#
#     2021-01-31  2021-02-28  2021-03-31  2021-04-30  2021-05-31  2021-06-30  \
# ...

# %% [markdown]
# So after filtering our dataframe down, we are left with 26 metro areas throughout NY state.

# %% [markdown]
# ### 2.4 Checking for NaN values

# %%
# Checking our dataframe for NaN values
print(f'There are {df_ny.isna().sum().sum()} NaNs in our original dataframe')

# Backfilling that single NaN
df_ny.fillna(method='bfill', inplace=True)

# Sanity check
print(f'There are {df_ny.isna().sum().sum()} NaNs after using backfill')
# Out:
# There are 1 NaNs in our original dataframe
# There are 0 NaNs after using backfill

# %% [markdown]
# Okay so in our entire dataframe we had a single Nan value we have to deal with, and because this is a time series, we used a backfill technique to deal with it.

# %% [markdown]
# ### 2.5 Price Distribution Within New York State

# %%
# Getting a list of the values for the last date in our time series
current_median_msa_home_prices = list(df_ny['2021-09-30'])

# Plotting the results
fig, ax = plt.subplots(figsize=(5,5))
plt.hist(current_median_msa_home_prices, bins=20)
plt.title('2021 NY State Median Home Price by Metro Area')
plt.xlabel('Median Home Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Okay so we have one significant outlier, which is guaranteed to be the NYC metro area, which we confirm below. However this does not necessarily mean that NYC is the best choice for investment, as our models may predict.

# %%
# Checking the median home price for New York in the most recent month. 
int(df_ny[df_ny['RegionName'] == 'New York, NY']['2021-09-30'])
# Out:
# 567059

# %% [markdown]
# ### 2.6 Melt Data Function

# %%
# This function was provided for us with the dataset at the beginning of this project
def melt_data(df):
    """
    Takes the zillow_data dataset in wide form or a subset of the zillow_dataset.  
    Returns a long-form datetime dataframe 
    with the datetime column names as the index and the values as the 'values' column.
    
    If more than one row is passes in the wide-form dataset, the values column
    will be the mean of the values from the datetime columns in all of the rows.
    """
    melted = pd.melt(df, id_vars=['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName'], var_name='time')
    melted['time'] = pd.to_datetime(melted['time'], infer_datetime_format=True)
    melted = melted.dropna(subset=['value'])
    return melted.groupby('time').aggregate({'value':'mean'})

# %% [markdown]
# ### 2.7 Time Series for all of New York State

# %%
# Melting the New York dataframe
df_ny_melted = melt_data(df_ny)

# Plotting the average time series for all of NY state
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(df_ny_melted)
plt.title('Averaged Median Home Prices in NY State from 2000 - 2021')
plt.xlabel('Year')
plt.ylabel('Averaged Median Home Price');

# %% [markdown]
# ### 2.8 Reshaping the Dataframe
#
# Our data is currently stored in 'wide format' and for our time series models to run, we need to convert our data into 'long format' where the values are stored vertically.

# %%
# The code in this cell came courtesy of the other group working on this project 
df = pd.DataFrame()
for i in df_ny['RegionName']:
    x = melt_data(df_ny[df_ny['RegionName'] == i])
    df = pd.concat([df, x], axis=1)
    df.rename(columns = {'value':i}, inplace = True)
    
df.head()
# Out:
#             New York, NY  Buffalo, NY  Rochester, NY  Albany, NY  \
# time
# 2000-01-31      225438.0      93968.0       100972.0    108218.0
# 2000-02-29      226785.0      94487.0       100678.0    108769.0
# 2000-03-31      227997.0      94871.0       100670.0    109063.0
# 2000-04-30      230383.0      95602.0       100915.0    109786.0
# 2000-05-31      232604.0      96126.0       101426.0    110293.0
#
#             Syracuse, NY  Utica, NY  Binghamton, NY  Kingston, NY  \
# time
# 2000-01-31       83512.0    70873.0         72439.0      121457.0
# 2000-02-29       83785.0    71222.0         72755.0      122299.0
# 2000-03-31       84042.0    71484.0         73045.0      123132.0
# 2000-04-30       84537.0    72079.0         73541.0      124778.0
# 2000-05-31       85003.0    72541.0         73906.0      126087.0
#
#             Jamestown, NY  Glens Falls, NY  ...  Olean, NY  Auburn, NY  \
# time                                        ...
# ...

# %% [markdown]
# ### 2.9 Shortening our Time Series
#
# There is a massive feature of our raw dataset that must be addressed. New York, like everywhere else in America, had its house prices slashed during the 2008 financial crisis. If we train our models on this entire dataset, our models might be overly influenced by this relatively rare crash, especially since our business use case requires we only look forward by one year. So to avoid hurting our models performance in validation tests and future predictions, we are going to only train our models on data from January of 2012 onward.

# %%
# Making a list of the column names that track prices from 2000 through the end of 2011
df_2012 = df['2012-01-31':]

# Examining the new shape
print(df_2012.shape)

# Sanity check
df_2012.head()
# Out:
# (117, 26)
#             New York, NY  Buffalo, NY  Rochester, NY  Albany, NY  \
# time
# 2012-01-31      380322.0     125593.0       125108.0    178740.0
# 2012-02-29      379024.0     125425.0       124755.0    178796.0
# 2012-03-31      377954.0     125586.0       124531.0    178624.0
# 2012-04-30      377247.0     125791.0       124841.0    178543.0
# 2012-05-31      376978.0     126051.0       125304.0    178792.0
#
#             Syracuse, NY  Utica, NY  Binghamton, NY  Kingston, NY  \
# time
# 2012-01-31      121600.0   107716.0        108445.0      203465.0
# 2012-02-29      121690.0   107516.0        108659.0      203059.0
# 2012-03-31      121882.0   107416.0        108418.0      202918.0
# 2012-04-30      122084.0   107370.0        108147.0      201539.0
# 2012-05-31      122463.0   107769.0        108238.0      201344.0
#
#             Jamestown, NY  Glens Falls, NY  ...  Olean, NY  Auburn, NY  \
# time                                        ...
# ...

# %% [markdown]
# ### 2.10 Train Test Split
#
# In order to validate our models and determine if our methods are effective, we will need to split our time series data into a train set and a test set. In the context of time series, the train will be the first 80% of our time series, and the test set will be the last 20%. Our post January 2012 data covers 9.75 years, meaning our train set will have a length of 7.8 years, and a test set of 2 years. This ratio of training data to test data will help to jusitfy the predictions we make for the the coming year. This is because if our models can accurately predict values 2 years out, based on 7.8 years of data, we can be more confident that our models accurately predict values 1 year from now, based on 9.75 years of data.

# %%
# Printing out the lengths of our unsplit time series 
print(f'Whole series lengths: {len(df_2012)} \n')

# Manually dividing the data into train and test sets
train = df_2012[:'2019-10-30']
test = df_2012['2019-10-30':]

# Printing the lengths of our new train and test sets
print(f'Train set lengths: {len(train)}')
print(f'Test set lengths: {len(test)} \n')

# Checking that the proportions are how we want them 
print(f'Train proportion = {round(len(train) / len(df_2012),1)}')
print(f'Test proportion = {round(len(test) / len(df_2012),1)} \n')

# Checking the length in years of our train and test sets
print(f'Train set length in years: {round(len(train) / 12, 2)}')
print(f'Test set length in years: {round(len(test) / 12, 2)}')
# Out:
# Whole series lengths: 117
#
# Train set lengths: 93
# Test set lengths: 24
#
# Train proportion = 0.8
# Test proportion = 0.2
#
# Train set length in years: 7.75
# Test set length in years: 2.0

# %% [markdown]
# ### 2.11 Establishing a Performance Baseline Before Modeling
#
# In order to determine whether or not modeling is even going to help in this business context, we will want to compare how well our models perform to  the performance of a simple, EDA based approach.

# %%
# These lists will hold the names of each metro area, as well as that area's ROI from 2012 to 2021
names = []
historical_roi = []

# This for loop adds the information to the two lists
for i in range(len(train.columns)):
    
    clean_name = train.columns[i][:-4]
    
    initial_val = train[train.columns[i]]['2012-01-31']
    present_val = train[train.columns[i]]['2019-09-30']
    
    roi = round(((present_val - initial_val) / initial_val) * 100, 2)
    
    names.append(clean_name)
    historical_roi.append(roi)

# Turning the data into a pandas dataframe
roi_df = pd.DataFrame()
roi_df['City'] = names
roi_df['% ROI'] = historical_roi
roi_df.sort_values(['% ROI'], inplace=True, ascending=False)
roi_df.set_index('City', inplace=True)

# Plotting the historical data 
fig, ax = plt.subplots(figsize=(20,5))
plt.bar(roi_df.index, roi_df['% ROI'])
plt.title('% ROI by Metro Area 2012 - 2019')
plt.xlabel('Metro Area')
plt.ylabel('% ROI')
plt.xticks(rotation=45)
plt.axhline(0, color='k')
plt.show()

# Displaying our top five choices based on EDA
roi_df.head()
# Out:
#               % ROI
# City
# Seneca Falls  40.61
# Buffalo       38.55
# Malone        38.26
# Cortland      37.38
# Batavia       33.75

# %% [markdown]
# Now that we know which 5 metro areas had the largest positive change in values from 2012 to 2019, we need to calculate how much net profit we would have made if we selected those five areas for investment in 2019. We will later compare this figure to our model evaluation results.

# %%
# Our top five choices based on EDA results
top_5 = ['Seneca Falls, NY', 'Buffalo, NY', 'Malone, NY', 'Cortland, NY', 'Batavia, NY']

# These two lists will track our buy and sell numbers
buys = []
sells = []

# Getting the median values for 2019 (buys) and 2021 (sells)
for i in top_5:
    buys.append(df_2012[i]['2019-09-30'])
    sells.append(df_2012[i]['2021-09-30'])

# Calculating the ROI we would have achieved
eda_roi = round( ((sum(sells) - sum(buys)) / sum(buys) ) * 100, 2)

# Printing the ROI
print(f'Using an EDA approach, we could have achieved {eda_roi}% ROI from 2019 to 2021')
# Out:
# Using an EDA approach, we could have achieved 17.72% ROI from 2019 to 2021

# %% [markdown]
# ## 3. Modeling

# %% [markdown]
# ### 3.1 Writing the Necessary Functions
#
# Because we want to find the five metro areas that are the most optimal for real estate investment within New York State, we are going to want to run time series models on every metro area individually. Doing this manually on all 26 quickly becomes unreasonable, so we are writing some functions to do the steps for us.

# %%
def log_transform(series_i):
    
    '''Takes in a series and returns the log transformed version of that series'''
    
    log_transformed = np.log(series_i)
    dropped_nans = log_transformed.dropna()
    return dropped_nans

# %%
def run_auto_arima(series_i):
    
    '''Runs a grid search on the series passed in, then instantiates and fits 
    an ARIMA model with those hyperparameters, then returns that fit model. '''
    
    gridsearch = auto_arima(series_i,
                            start_p = 0,
                            max_p = 3,
                            d = 0, 
                            max_d = 3, 
                            start_q = 0,
                            max_q = 3,
                            seasonal=True,
                            m = 12,
                            suppress_warnings=True)
    
    model = ARIMA(series_i, 
                  order = gridsearch.order, 
                  seasonal_order = gridsearch.seasonal_order,
                  enforce_stationarity=False)
    
    return model.fit()

# %%
def run_arima_model(i, steps, df):
    
    '''This function takes i, representing the index of one of our time series,
    steps, which is the number of periods after the end of the 
    sample you want to make a prediction for, and df, the dataframe the series
    is stored in. It log transforms the series, runs run_auto_arima, gets the 
    forecast from the fit model, and inverse log transforms that forecast series
    back into the original units.'''
    
    series = df.iloc[:, i:i+1]
    
    name = series.columns[0]
    
    log_series = log_transform(series)
    
    model = run_auto_arima(log_series)

    log_forecast = model.get_forecast(steps)
    forecast_series = e ** log_forecast.summary_frame()
    
    return name, series, forecast_series

# %%
def plot_results(i, steps, df):
    
    '''plot_results runs run_arima_model() and plots the results.'''
    
    name, original_series, forecast_series = run_arima_model(i, steps, df)

    fig, ax = plt.subplots(figsize=(15, 7))
    plt.plot(original_series)
    plt.plot(forecast_series['mean'])
    ax.fill_between(forecast_series.index, forecast_series['mean_ci_lower'], 
                    forecast_series['mean_ci_upper'], color='k', alpha=0.1)
    plt.title(name)
    plt.legend(['Original','Predicted'], loc='lower right')
    plt.xlabel('Year')
    plt.ylabel('Median Home Price')
    plt.show()
    
    forecast = round(forecast_series['mean'][11])
    low_int =  round(forecast_series['mean_ci_lower'][11])
    high_int = round(forecast_series['mean_ci_upper'][11])
    
    print(f'12 month forecast: {forecast}')
    print(f'95% confidence that the true future value is between {low_int}, and {high_int}')

# %%
def evaluate_models(df1, df2):
    
    '''This function takes in two dataframes (train and test in our case), 
    and returns a dataframe with how accurate the models fit to the train 
    set were in predicting the test set values.'''

    names = []
    actuals = []
    preds = []
    perc_errors = []
    
    for i in range(len(train.columns)):
        
        name, series, forecast_series = run_arima_model(i, 24, df1)
        
        clean_name = name[:-4]
        
        actual_val = df2[name][-1]
        predicted_val = forecast_series.iloc[23, 0]
        error = abs(actual_val - predicted_val)
        percent_error = (error/ actual_val) * 100
        
        names.append(clean_name)
        actuals.append(f'{round(actual_val):,}')
        preds.append(f'{round(predicted_val):,}')
        perc_errors.append(round(percent_error, 2))
        
        # print(train.columns[i][:-4], 'done', f'{i+1}/26')
        
    
    results_df = pd.DataFrame(index=names)
    results_df['2021 Actual'] = actuals 
    results_df['2021 Predicted'] = preds
    results_df['% Error'] = perc_errors
    results_df.sort_values(by='% Error', inplace=True)
    
    return results_df

# %%
def generate_predictions(df, steps):
    
    '''Similar to evaluate_models(), this function takes in a dataframe,
    and a specific number of steps, and returns a dataframe of the 
    future predictions the specified number of steps past the end of 
    the sample.'''
    
    names = []
    current_vals = []
    pred_vals = []
    net_profits = []
    ROI_strings = []
    
    count = 0
    for i in range(len(df.columns)):
        
        count += 1
        
        name, series, forecast = run_arima_model(i, steps, df)
        
        clean_name = name[:-4]
        print(clean_name)
        
        cur_val = series.iloc[-1, 0]
        pred_val = forecast.iloc[steps-1, 0]
        net_prof = round(pred_val - cur_val , 2)
        roi = int(round(((pred_val - cur_val) / cur_val) * 100, 2))
        
        names.append(clean_name)
        current_vals.append(f'{round(cur_val):,}')
        pred_vals.append(f'{round(pred_val):,}')
        net_profits.append(f'{round(net_prof):,}')
        ROI_strings.append(f'{roi}%') 
        
        if count == 26:
            break
    
    
    results_df = pd.DataFrame()
    results_df['City'] = names
    results_df.set_index(['City'])
    results_df['Current Value'] = current_vals
    results_df['Predicted Value'] = pred_vals
    results_df['Net Profit'] = net_profits
    results_df['ROI'] = ROI_strings
    
    return results_df

# %% [markdown]
# ### 3.2 Model Evaluation
#
# In order to ensure that our predictions for the future are within some reasonable range of accuracy, we are going to see how well our models perform on data we already have. The evaluate_models( ) function will track how different our models predictions for September of 2021 are from the actual observed values for September 2021. Of course the models have only been trained on the data spanning from 2012 to 2019, and their predictions for September of 2021 have been made while completely blind to the test data, which spans from 2019 to 2021.

# %%
# This dataframe will show us how accurate our models are 
eval_df = evaluate_models(train, test)

# Displaying the dataframe
eval_df
# Out:
#              2021 Actual 2021 Predicted  % Error
# Jamestown        129,296        130,477     0.91
# Oneonta          169,516        166,218     1.95
# Plattsburgh      162,965        155,974     4.29
# Malone           125,937        119,691     4.96
# Amsterdam        133,850        123,948     7.40
# Utica            171,678        155,361     9.50
# Cortland         145,712        131,509     9.75
# Kingston         350,270        314,420    10.24
# Glens Falls      227,012        202,803    10.66
# Seneca Falls     140,798        125,191    11.08
# Ithaca           250,626        221,356    11.68
# Watertown        165,625        144,588    12.70
# Rochester        194,732        168,574    13.43
# Batavia          159,914        137,928    13.75
# Syracuse         178,075        152,728    14.23
# Corning          129,423        110,847    14.35
# Gloversville     147,087        124,507    15.35
# Buffalo          225,838        186,987    17.20
# ...

# %%
# Calculating the average error using the dataframe above 
average_error = str(round(sum([int(i) for i in eval_df['% Error']]) / len(eval_df) , 2)) + '%'

# Printing the result
print(f"On average our model based predictions were {average_error} off from the observed values.")
# Out:
# On average our model based predictions were 12.85% off from the observed values.

# %% [markdown]
# So on average our model's predictions were roughly 13% off from the actual values from our test set. We are happy with this validation results since we aren't tuning any of the models manually. In addition, this 13% average error is the result of our models training on eight years of data, and predicting two years out, in our final recommendations we will use ten years of training data to predict one year out. This means our predictions for the future will likely be even closer to the true future values than the ones in this validation test were.

# %%
# Getting predictions from our models for September of 2021
model_predictions_2021 = generate_predictions(train, 24)

# Checking out the results
model_predictions_2021
# Out:
# New York
# Buffalo
# Rochester
# Albany
# Syracuse
# Utica
# Binghamton
# Kingston
# Jamestown
# Glens Falls
# Watertown
# Ogdensburg
# Ithaca
# Corning
# Elmira
# Plattsburgh
# Olean
# Auburn
# Hudson
# Oneonta
# Batavia
# Gloversville
# Malone
# Amsterdam
# Cortland
# Seneca Falls
#             City Current Value Predicted Value Net Profit  ROI
# 19       Oneonta       152,604         166,218     13,614   8%
# 18        Hudson       261,419         283,025     21,606   8%
# 2      Rochester       156,811         168,574     11,763   7%
# 1        Buffalo       174,006         186,987     12,981   7%
# 9    Glens Falls       191,287         202,803     11,516   6%
# 21  Gloversville       117,966         124,507      6,541   5%
# 4       Syracuse       144,541         152,728      8,187   5%
# 23     Amsterdam       116,976         123,948      6,972   5%
# 22        Malone       113,568         119,691      6,123   5%
# ...

# %% [markdown]
# Now we will see how our model ROI for 2019 to 2021 compares our previous EDA method.

# %%
# A list of the top five metro areas output by our models
model_top_5 = ['Kingston, NY', 'Jamestown, NY', 'Utica, NY', 'Oneonta, NY', 'Hudson, NY']

# Variables to track initial and final investment value
buys = 0
sells = 0

# Adding the relevant values
for i in model_top_5:
    buys  += df_2012[i]['2019-09-30']
    sells += df_2012[i]['2021-09-30']

# Calculating the ROI
model_roi_2019 = round(((sells - buys) / buys) * 100 , 2)

# Displaying the results
print(f'Using modeling, we could have achieved {model_roi_2019}% ROI from 2019 to 2021')
# Out:
# Using modeling, we could have achieved 29.46% ROI from 2019 to 2021

# %% [markdown]
# So switching from an EDA based approach, to modeling would have taken us from 17.7% ROI to 29.46% ROI for September 2019 to September 2021. This tells us that our modeling efforts are not in vain, and are certainly worth the effort in terms of this specific business outcome.

# %% [markdown]
# ## 4. Predictions
#
# The entire aim of this project is to provide possible clients investing in NY real estate a starting point by recommending the 5 NY metro areas most ripe for short term investment. We are finally at the stage where we can make those predictions. Using the same modeling process as we did above, we will now apply our models to the entire 2012 to 2021 dataset, and predict the September 2022 median home value for each of our 26 metro areas. We will then take these 26 growth estimates, sorted by highest ROI, and select the top five as our recommendations.

# %%
# Generating predictions one year past our entire 2012 to 2021 dataset
recommendation_df = generate_predictions(df_2012, 12)

# Looking at the results
recommendation_df.iloc[1:,:]
# Out:
# New York
# Buffalo
# Rochester
# Albany
# Syracuse
# Utica
# Binghamton
# Kingston
# Jamestown
# Glens Falls
# Watertown
# Ogdensburg
# Ithaca
# Corning
# Elmira
# Plattsburgh
# Olean
# Auburn
# Hudson
# Oneonta
# Batavia
# Gloversville
# Malone
# Amsterdam
# Cortland
# Seneca Falls
#             City Current Value Predicted Value Net Profit  ROI
# 14        Elmira       125,692         185,797     60,105  47%
# 11    Ogdensburg       100,270         145,702     45,432  45%
# 0       New York       567,059         594,362     27,303   4%
# 5          Utica       171,678         223,947     52,269  30%
# 18        Hudson       344,878         357,506     12,628   3%
# 15   Plattsburgh       162,965         169,108      6,143   3%
# 6     Binghamton       151,353         193,263     41,910  27%
# 8      Jamestown       129,296         163,074     33,778  26%
# 22        Malone       125,937         158,192     32,255  25%
# ...

# %% [markdown]
# ## 5. Conclusions

# %% [markdown]
# ### 5.1 Modeling vs EDA
#
# In our attempt to find out if our models were worth the effort, we found very encouraging evidence that they were. When we used an EDA based approach on our train set to generate a list of 5 cities to invest in, and then simulated investing in those 5 cities on our test set, we achieved a 17.7% return on investment. Then when we used modeling to predict which 5 cities in New York would be the best choices for investment over the course of our test set, we achieved a 29.5% return on investment. This told us that even if our final models are not extremely accurate, their recommendations are still valuable.

# %% [markdown]
# ### 5.2 Model Accuracy
#
# Obviously only time will tell if our models prove accurate. We think it's important to note two seperate ways in which model accuracy could be gauged.
#
# The first being how different our models' predictions for the future dollar values are to the true future values. This is the metric we tested when we trained our models on the training set, and measured their guesses against the test set. In that step, we found that on average the prediction from our models was 13% off the final observed value, a results we were happy with.
#
# The second way to gauge model performance is comparison to a modeless baseline, and at least in our validation step, we found our models to perform better than an EDA based methodology.
#
# Time series forecasting is a tricky business, as all future predicting tasks are. The top ROI estimates we generated could be called *extremely optimistic*. Some of these estimates for one year in the future outperform the top historical ROIs we saw from 2012-2019, nearly a decade. However even if our models are not incredibly accurate in their dollar amount predictions, due to their performance compared to EDA based methods in our validation set, we believe our models have significant value in pointing to which 5 metro areas would be the best for short term investment.

# %% [markdown]
# ### 5.3 Plotting the Top Five Area Recommendations
#
# These five charts show the top 5 NY metro areas by ROI one year out, as predicted by our models, and serve as our final recommendations.

# %%
plot_results(14, 12, df_2012)
# Out:
# 12 month forecast: 185797
# 95% confidence that the true future value is between 170398, and 202587

# %%
plot_results(11, 12, df_2012)
# Out:
# 12 month forecast: 145702
# 95% confidence that the true future value is between 132202, and 160582

# %%
plot_results(5, 12, df_2012)
# Out:
# 12 month forecast: 223947
# 95% confidence that the true future value is between 210731, and 237993

# %%
plot_results(6, 12, df_2012)
# Out:
# 12 month forecast: 193263
# 95% confidence that the true future value is between 181553, and 205728

# %%
plot_results(8, 12, df_2012)
# Out:
# 12 month forecast: 163074
# 95% confidence that the true future value is between 158421, and 167864

# %% [markdown]
# ### 5.4 Facebook Prophet
#
# We also did additional Facebook Prophet time series modeling, to cross reference the results we achieved here. That analysis is available in the 'Facebook Prophet Notebook' in our github repo.
